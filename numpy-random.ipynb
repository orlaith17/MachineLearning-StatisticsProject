# %% [markdown]
# # The Numpy Random Package
#
# [Official Documentation](https://numpy.org/doc/stable/reference/random/index.html)
# ***

# %%
# efficient numerical arrays
import numpy as np
# plotting
import matplotlib.pyplot as plt

# %%
# change default plot style
plt.style.use('fivethirtyeight')
# change default figure size of plt
plt.rcParams['figure.figsize'] = [12,8]

# %% [markdown]
# Seeds can be passed to any of the BitGenerators.[1]

# %% [markdown]
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# show all elements in array, right-click enable scrolling to create scrolling bar
s
# Out:
# array([-8.18779380e-02, -2.96429076e-02,  1.24136914e-02,  7.87829519e-03,
#        -8.85651169e-02, -9.15998272e-03, -2.61160788e-03, -8.85686204e-02,
#         3.25630809e-02, -4.99133200e-02, -3.21421363e-02, -1.15888580e-01,
#        -7.17354552e-02, -1.72605156e-02, -4.03924442e-02, -2.29462015e-02,
#         2.33487267e-01, -7.89392522e-02,  7.64443113e-02,  5.19121126e-02,
#         7.17851578e-02, -5.20687006e-02,  8.05242060e-02, -6.74999916e-02,
#        -1.05696711e-02, -7.15914779e-02, -1.88881361e-01, -1.60031767e-01,
#        -9.53761770e-02,  7.67296493e-02, -9.98264540e-02,  2.14304750e-01,
#        -3.31646763e-02, -1.01450098e-01, -7.40737433e-02, -1.09195489e-01,
#         5.36588522e-02,  1.79059324e-02,  7.19871533e-02,  8.06962489e-03,
#        -6.91414667e-02, -1.11956409e-01,  1.06172769e-01,  1.88246960e-01,
#        -5.54318490e-02,  9.49943172e-02, -8.06700352e-02,  1.23369182e-01,
# ...

# %%
# look at the first 10 items
s[:10]
# Out:
# array([-0.08187794, -0.02964291,  0.01241369,  0.0078783 , -0.08856512,
#        -0.00915998, -0.00261161, -0.08856862,  0.03256308, -0.04991332])

# %%
abs(mu - np.mean(s))
# Out:
# 1.830271829073804e-06

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2))
plt.plot(bins,f,linewidth=2,color='r')
plt.show()

# %% [markdown]
# ## References
#
# [1] https://numpy.org/doc/stable/reference/random/index.html - look at ways to reference with footnotes in markdown

# %% [markdown]
# ***
# ## End
